# %% [markdown]
# # ** LLM CALL **

# %%
# all these below import packages are been installed in pyproject.toml file when we ran the uv add ...
from langchain_groq import ChatGroq
llm = ChatGroq(model="llama-3.1-8b-instant", temperature=0.6)

# %%
llm.invoke("bro tell me a funny joke on dogs")
# Out:
# AIMessage(content="Here's one:\n\nWhy did the dog go to the vet?\n\nBecause he was feeling a little ruff!\n\nHope that made you howl with laughter!")
